# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('drinks.csv')
df
# Out:
#                Beveage_category                                        Bevage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 240  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 242  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 243  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 244  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
df.rename(columns={'Beveage_category':'Beverage_categories'},inplace=True)

# %%
df.rename(columns={'Beveage_prep':'Beverage_prepration'},inplace=True)

# %%
df.rename(columns={'Bevage':'beverages'},inplace=True)

# %%
df.rename(columns={'Cal':'Calories'},inplace=True)

# %%
df
# Out:
#             Beverage_categories                                     beverages  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 240  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 242  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 243  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 244  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Beverage_categories      245 non-null    object
#  1   beverages                245 non-null    object
#  2   Beverage_prepration      245 non-null    object
#  3   Calories                 242 non-null    float64
#  4   Total_Fat(g)             245 non-null    object
#  5   Trans_Fat(g)             245 non-null    float64
#  6   Saturated_Fat(g)         245 non-null    float64
#  7   Sodium(g)                244 non-null    float64
#  8   Total_Carbohydrates(g)   245 non-null    int64
#  9   Cholesterol(mg)          244 non-null    float64
#  10  Dietary_Fibre (g)        245 non-null    int64
#  11  Sugars(g)                245 non-null    int64
#  12  Protein(g)               245 non-null    object
#  13  Vitamin_A(% DV)          245 non-null    object
# ...

# %%
df.count()
# Out:
# Beverage_categories        245
# beverages                  245
# Beverage_prepration        245
# Calories                   242
# Total_Fat(g)               245
# Trans_Fat(g)               245
# Saturated_Fat(g)           245
# Sodium(g)                  244
# Total_Carbohydrates(g)     245
# Cholesterol(mg)            244
# Dietary_Fibre (g)          245
# Sugars(g)                  245
# Protein(g)                 245
# Vitamin_A(% DV)            245
# Vitamin_C(% DV)            245
#  calcium(% DV)             245
# Iron(% DV)                 245
# Caffeine(mg)               243
# dtype: int64

# %%
df.describe()
# Out:
#          Calories  Trans_Fat(g)  Saturated_Fat(g)   Sodium(g)  \
# count  242.000000    245.000000        245.000000  244.000000
# mean   193.198347      1.295102          0.037551    6.381148
# std    103.855719      1.634508          0.071131    8.590729
# min      0.000000      0.000000          0.000000    0.000000
# 25%    120.000000      0.100000          0.000000    0.000000
# 50%    185.000000      0.500000          0.000000    5.000000
# 75%    260.000000      2.000000          0.100000   10.000000
# max    510.000000      9.000000          0.300000   40.000000
#
#        Total_Carbohydrates(g)   Cholesterol(mg)  Dietary_Fibre (g)   Sugars(g)
# count               245.000000       244.000000         245.000000  245.000000
# mean                126.710204        35.725410           0.930612   32.755102
# std                  83.030372        20.947377           2.510487   19.767222
# min                   0.000000         0.000000           0.000000    0.000000
# ...

# %%
df.dtypes
# Out:
# Beverage_categories         object
# beverages                   object
# Beverage_prepration         object
# Calories                   float64
# Total_Fat(g)                object
# Trans_Fat(g)               float64
# Saturated_Fat(g)           float64
# Sodium(g)                  float64
# Total_Carbohydrates(g)       int64
# Cholesterol(mg)            float64
# Dietary_Fibre (g)            int64
# Sugars(g)                    int64
# Protein(g)                  object
# Vitamin_A(% DV)             object
# Vitamin_C(% DV)             object
#  calcium(% DV)              object
# Iron(% DV)                  object
# Caffeine(mg)                object
# dtype: object

# %%
df.groupby('Beverage_categories').Beverage_categories.count()
# Out:
# Beverage_categories
# Classic Espresso Drinks                     58
# Coffee                                       4
# Frappuccino® Blended Coffee                 36
# Frappuccino® Blended Crème                  13
# Frappuccino® Light Blended Coffee           12
# Shaken Iced Beverages                       19
# Signature Espresso Drinks                   40
# Smoothies                                    9
# Tazo® Tea Drinks                            53
# Vanilla Latte (Or Other Flavoured Latte)     1
# Name: Beverage_categories, dtype: int64

# %%
df.groupby('beverages').beverages.count()
# Out:
# beverages
# Banana Chocolate Smoothie                               3
# Brewed Coffee                                           4
# Caffè Americano                                         4
# Caffè Latte                                            12
# Caffè Mocha (Without Whipped Cream)                    12
# Cappuccino                                             12
# Caramel                                                 3
# Caramel (Without Whipped Cream)                         9
# Caramel Apple Spice (Without Whipped Cream)             4
# Caramel Macchiato                                      12
# Coffee                                                 12
# Espresso                                                2
# Hot Chocolate (Without Whipped Cream)                  12
# Iced Brewed Coffee (With Classic Syrup)                 3
# Iced Brewed Coffee (With Milk & Classic Syrup)         10
# Java Chip                                               3
# ...

# %%
df.shape #it is showing rows and columns
# Out:
# (245, 18)

# %%
df.isnull()
# Out:
#      Beverage_categories  beverages  Beverage_prepration  Calories  \
# 0                  False      False                False     False
# 1                  False      False                False     False
# 2                  False      False                False     False
# 3                  False      False                False     False
# 4                  False      False                False     False
# ..                   ...        ...                  ...       ...
# 240                False      False                False     False
# 241                False      False                False     False
# 242                False      False                False     False
# 243                False      False                False     False
# 244                False      False                False     False
#
#      Total_Fat(g)  Trans_Fat(g)  Saturated_Fat(g)  Sodium(g)  \
# 0           False         False             False      False
# ...

# %%
import seaborn as sns
sns.heatmap(df.isnull()) #using heat map we see null value in white color
# Out:
# <Axes: >

# %%
df.isnull().sum() #check null values using isnull function
# Out:
# Beverage_categories        0
# beverages                  0
# Beverage_prepration        0
# Calories                   3
# Total_Fat(g)               0
# Trans_Fat(g)               0
# Saturated_Fat(g)           0
# Sodium(g)                  1
# Total_Carbohydrates(g)     0
# Cholesterol(mg)            1
# Dietary_Fibre (g)          0
# Sugars(g)                  0
# Protein(g)                 0
# Vitamin_A(% DV)            0
# Vitamin_C(% DV)            0
#  calcium(% DV)             0
# Iron(% DV)                 0
# Caffeine(mg)               2
# dtype: int64

# %%
df['Calories'].fillna(10,inplace=True) #filling null values

# %%
df['Sodium(g)'].fillna(2,inplace=True)

# %%
df['Cholesterol(mg)'].fillna(20,inplace=True)

# %%
df['Caffeine(mg)'].fillna(10,inplace=True)

# %%
df.isnull().sum() #checking again
# Out:
# Beverage_categories        0
# beverages                  0
# Beverage_prepration        0
# Calories                   0
# Total_Fat(g)               0
# Trans_Fat(g)               0
# Saturated_Fat(g)           0
# Sodium(g)                  0
# Total_Carbohydrates(g)     0
# Cholesterol(mg)            0
# Dietary_Fibre (g)          0
# Sugars(g)                  0
# Protein(g)                 0
# Vitamin_A(% DV)            0
# Vitamin_C(% DV)            0
#  calcium(% DV)             0
# Iron(% DV)                 0
# Caffeine(mg)               0
# dtype: int64

# %%
#checking duplicate values
df[df.duplicated()]
# Out:
#        Beverage_categories                                       beverages  \
# 154       Tazo® Tea Drinks                                       Tazo® Tea
# 210  Shaken Iced Beverages  Iced Brewed Coffee (With Milk & Classic Syrup)
#
#     Beverage_prepration  Calories Total_Fat(g)  Trans_Fat(g)  \
# 154               Short       0.0            0           0.0
# 210             2% Milk     180.0            2           1.0
#
#      Saturated_Fat(g)  Sodium(g)  Total_Carbohydrates(g)   Cholesterol(mg)  \
# 154               0.0        0.0                        0              0.0
# 210               0.1       10.0                       55             36.0
#
#      Dietary_Fibre (g)  Sugars(g) Protein(g)  Vitamin_A(% DV)   \
# 154                  0          0           0               0%
# 210                  0         36           4               6%
#
#     Vitamin_C(% DV)  calcium(% DV)  Iron(% DV)  Caffeine(mg)
# 154              0%              0%          0%       Varies
# ...

# %%
df.drop_duplicates()
df.reset_index()
# Out:
#      index         Beverage_categories  \
# 0        0                      Coffee
# 1        1                      Coffee
# 2        2                      Coffee
# 3        3                      Coffee
# 4        4     Classic Espresso Drinks
# ..     ...                         ...
# 240    240  Frappuccino® Blended Crème
# 241    241  Frappuccino® Blended Crème
# 242    242  Frappuccino® Blended Crème
# 243    243  Frappuccino® Blended Crème
# 244    244  Frappuccino® Blended Crème
#
#                                         beverages Beverage_prepration  \
# 0                                   Brewed Coffee               Short
# 1                                   Brewed Coffee                Tall
# 2                                   Brewed Coffee              Grande
# 3                                   Brewed Coffee               Venti
# 4                                     Caffè Latte   Short Nonfat Milk
# ...

# %%
df.reset_index()
# Out:
#      index         Beverage_categories  \
# 0        0                      Coffee
# 1        1                      Coffee
# 2        2                      Coffee
# 3        3                      Coffee
# 4        4     Classic Espresso Drinks
# ..     ...                         ...
# 240    240  Frappuccino® Blended Crème
# 241    241  Frappuccino® Blended Crème
# 242    242  Frappuccino® Blended Crème
# 243    243  Frappuccino® Blended Crème
# 244    244  Frappuccino® Blended Crème
#
#                                         beverages Beverage_prepration  \
# 0                                   Brewed Coffee               Short
# 1                                   Brewed Coffee                Tall
# 2                                   Brewed Coffee              Grande
# 3                                   Brewed Coffee               Venti
# 4                                     Caffè Latte   Short Nonfat Milk
# ...

# %%
#it is showing Frappuccino® Blended Crème which has more than 300 Calories
filtered_df = df[(df['Beverage_categories'] == 'Frappuccino® Blended Crème') & (df['Calories'] >= 300)]
filtered_df
# Out:
#             Beverage_categories                                     beverages  \
# 238  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 239  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 240  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
#
#     Beverage_prepration  Calories Total_Fat(g)  Trans_Fat(g)  \
# 238   Venti Nonfat Milk     310.0          0.2           0.1
# 239          Whole Milk     350.0            6           3.0
# 240             Soymilk     320.0          3 2           0.4
#
#      Saturated_Fat(g)  Sodium(g)  Total_Carbohydrates(g)   Cholesterol(mg)  \
# 238               0.0        5.0                      260             70.0
# 239               0.2       15.0                      260             70.0
# 240               0.0        0.0                      250             67.0
#
#      Dietary_Fibre (g)  Sugars(g) Protein(g)  Vitamin_A(% DV)   \
# ...

# %%
#now if we only see the bevrage column
filtered_df = df[(df['Beverage_categories'] == 'Frappuccino® Blended Crème') & (df['Calories'] >= 300)] ['beverages']
filtered_df
# Out:
# 238    Strawberries & Crème (Without Whipped Cream)
# 239    Strawberries & Crème (Without Whipped Cream)
# 240    Strawberries & Crème (Without Whipped Cream)
# Name: beverages, dtype: object

# %%
#high number of beverage in perticular category
df['Beverage_categories'].value_counts()
# Out:
# Classic Espresso Drinks                     58
# Tazo® Tea Drinks                            53
# Signature Espresso Drinks                   40
# Frappuccino® Blended Coffee                 36
# Shaken Iced Beverages                       19
# Frappuccino® Blended Crème                  13
# Frappuccino® Light Blended Coffee           12
# Smoothies                                    9
# Coffee                                       4
# Vanilla Latte (Or Other Flavoured Latte)     1
# Name: Beverage_categories, dtype: int64

# %%
#if we want to see top 5
df['Beverage_categories'].value_counts().head(5)
# Out:
# Classic Espresso Drinks        58
# Tazo® Tea Drinks               53
# Signature Espresso Drinks      40
# Frappuccino® Blended Coffee    36
# Shaken Iced Beverages          19
# Name: Beverage_categories, dtype: int64

# %%
#how many beverage is present related to hotchoclate
df[df['beverages']=='hot choclate'] #there is no hot choclate in owr data set
# Out:
# Empty DataFrame
# Columns: [Beverage_categories, beverages, Beverage_prepration, Calories, Total_Fat(g), Trans_Fat(g), Saturated_Fat(g), Sodium(g), Total_Carbohydrates(g) , Cholesterol(mg), Dietary_Fibre (g), Sugars(g), Protein(g) , Vitamin_A(% DV) , Vitamin_C(% DV),  calcium(% DV) , Iron(% DV) , Caffeine(mg)]
# Index: []

# %%
df['beverages'].unique()
# Out:
# array(['Brewed Coffee', 'Caffè Latte', 'Soymilk',
#        'Caffè Mocha (Without Whipped Cream)',
#        'Vanilla Latte (Or Other Flavoured Latte)', 'Caffè Americano',
#        'Cappuccino', 'Espresso', 'Skinny Latte (Any Flavour)',
#        'Caramel Macchiato',
#        'White Chocolate Mocha (Without Whipped Cream)',
#        'Hot Chocolate (Without Whipped Cream)',
#        'Caramel Apple Spice (Without Whipped Cream)', 'Tazo® Tea',
#        'Tazo® Chai Tea Latte', 'Tazo® Green Tea Latte',
#        'Tazo® Full-Leaf Tea Latte',
#        'Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)',
#        'Iced Brewed Coffee (With Classic Syrup)',
#        'Iced Brewed Coffee (With Milk & Classic Syrup)',
#        'Shaken Iced Tazo® Tea (With Classic Syrup)',
#        'Shaken Iced Tazo® Tea Lemonade (With Classic Syrup)',
#        'Banana Chocolate Smoothie', 'Orange Mango Banana Smoothie',
#        'Strawberry Banana Smoothie', 'Coffee',
# ...

# %%
df.sort_values(by='Calories') #we can see less calories drink
# Out:
#              Beverage_categories  \
# 105             Tazo® Tea Drinks
# 103             Tazo® Tea Drinks
# 104             Tazo® Tea Drinks
# 106             Tazo® Tea Drinks
# 154             Tazo® Tea Drinks
# ..                           ...
# 84     Signature Espresso Drinks
# 129             Tazo® Tea Drinks
# 218  Frappuccino® Blended Coffee
# 86     Signature Espresso Drinks
# 85     Signature Espresso Drinks
#
#                                          beverages Beverage_prepration  \
# 105                                      Tazo® Tea              Grande
# 103                                      Tazo® Tea               Short
# 104                                      Tazo® Tea                Tall
# 106                                      Tazo® Tea               Venti
# 154                                      Tazo® Tea               Short
# ..                                             ...                 ...
# ...

# %%
df.sort_values(by='Calories',ascending=False) #high calories drink
# Out:
#              Beverage_categories  \
# 85     Signature Espresso Drinks
# 86     Signature Espresso Drinks
# 218  Frappuccino® Blended Coffee
# 129             Tazo® Tea Drinks
# 84     Signature Espresso Drinks
# ..                           ...
# 105             Tazo® Tea Drinks
# 104             Tazo® Tea Drinks
# 103             Tazo® Tea Drinks
# 154             Tazo® Tea Drinks
# 106             Tazo® Tea Drinks
#
#                                          beverages Beverage_prepration  \
# 85   White Chocolate Mocha (Without Whipped Cream)             2% Milk
# 86   White Chocolate Mocha (Without Whipped Cream)             Soymilk
# 218              Java Chip (Without Whipped Cream)          Whole Milk
# 129                          Tazo® Green Tea Latte             2% Milk
# 84   White Chocolate Mocha (Without Whipped Cream)   Venti Nonfat Milk
# ..                                             ...                 ...
# ...

# %%
df.iloc[:,0:4]
# Out:
#             Beverage_categories                                     beverages  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 240  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 242  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 243  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 244  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
df.loc[:,'Beverage_categories':'Calories'] #by lable
# Out:
#             Beverage_categories                                     beverages  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 240  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 242  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 243  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 244  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
x='Calories'
fig=plt.figure(figsize=(20,11))
x1=plt.subplot()
x1.plot(df[x],marker='x',color='r',linewidth=3)

# %%
a=df['Beverage_categories']
b=df['Calories']
c=['red']
fig=plt.figure(figsize=(35,10))
plt.bar(a,b,color=c)
plt.xlabel('Beverage_categories')
plt.ylabel('Calories')
plt.title('Barplot')
plt.grid(True)#for grid
plt.show()

# %%
c=df['Beverage_categories']
d=df['Protein(g) ']
fig=plt.figure(figsize=(15,5))
plt.scatter(d,c,marker='^',s=200,c='y')
plt.xlabel('Protein')
plt.ylabel('Beverage categories')

plt.title('Scatter plot')
# Out:
# Text(0.5, 1.0, 'Scatter plot')

# %%
a=df['Calories']
fig=plt.figure(figsize=(5,5))
plt.boxplot(a)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1caba6ee150>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1caba7ed610>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1caba555c10>],
#  'medians': [<matplotlib.lines.Line2D at 0x1caba7ee390>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1caba7ec210>],
#  'means': []}

# %%
a=range(0,245)
b=df['Sugars(g)']
fig=plt.figure(figsize=(15,5))
plt.stackplot(a,b)

# %%
sns.catplot(x='Beverage_prepration',data=df,kind='count',height=6, aspect=3)
